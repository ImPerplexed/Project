# %%
data_dict = {"Job": [],
            "Company":[],
             "Location":[],
            "Detail": []}

# %%
import pandas as pd

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
# direct the webdriver to where the browser file is:
driver_path = r"C:\Users\admin\geckodriver.exe"
driver = webdriver.Firefox(executable_path=driver_path)
# your secret credentials:
email = "buituankiet132000@gmail.com"
password = "pass:1+1*2=3?"
# Go to linkedin and login
driver.get('https://www.linkedin.com/login')
time.sleep(3)
driver.find_element_by_id('username').send_keys(email)
driver.find_element_by_id('password').send_keys(password)
driver.find_element_by_id('password').send_keys(Keys.RETURN)
# Out:
# <ipython-input-4-16e6dfb28bc0>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path)
# <ipython-input-4-16e6dfb28bc0>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('username').send_keys(email)
# <ipython-input-4-16e6dfb28bc0>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('password').send_keys(password)
# <ipython-input-4-16e6dfb28bc0>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('password').send_keys(Keys.RETURN)

# %%
driver.get("https://www.linkedin.com/jobs/")
time.sleep(3)
# find the keywords/location search bars:
search_bars = driver.find_elements_by_class_name('jobs-search-box__text-input')
search_keywords = search_bars[0]
search_keywords.send_keys("Data Analyst")
    
search_location = search_bars[3]
search_location.send_keys("Viet Nam")
search_location.send_keys(Keys.RETURN)
# Out:
# <ipython-input-5-e1f81f35b01e>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   search_bars = driver.find_elements_by_class_name('jobs-search-box__text-input')

# %%
# get a list of all the listings elements's in the side bar
list_items = driver.find_elements_by_class_name("occludable-update")
# # scrolls a single page:
for job in list_items:
    # executes JavaScript to scroll the div into view
    driver.execute_script("arguments[0].scrollIntoView();", job)
    job.click()
    time.sleep(3)
    # get info:
    [position, company, location] = job.text.split('\n')[:3]
    details = driver.find_element_by_id("job-details").text
    # do what you want with that info...
    data_dict["Job"].append(position)
    data_dict["Company"].append(company)
    data_dict["Location"].append(location)
    data_dict["Detail"].append(details)
# Out:
# <ipython-input-13-cc056abdad83>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   list_items = driver.find_elements_by_class_name("occludable-update")
# <ipython-input-13-cc056abdad83>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   details = driver.find_element_by_id("job-details").text

# %%
df = pd.DataFrame(data_dict)
display(df)
# Out:
#                                                   Job  \
# 0                                        Data Analyst
# 1                     Business Data Analyst Team Lead
# 2   Fraud Data Analyst (Bangkok based, relocation ...
# 3                                      Data Scientist
# 4                   Data Scientist in logistics field
# 5                                      Data Scientist
# 6                                        Data Analyst
# 7                                      Data Scientist
# 8                                 Senior Data Analyst
# 9                                 Retail Data Analyst
# 10  Data Scientist - QuantumBlack - Ho Chi Minh Ci...
# 11                    Data Analyst (Customer Service)
# 12                        Business Operations Analyst
# 13  ShopeeFood - Delivery Operations, Driver Data ...
# 14                          Data Scientist (Analysis)
# 15  People Data Analyst(Bangkok based, relocation ...
# 16                                   Business Analyst
# 17  People Data Analyst(Bangkok based, relocation ...
# 18                        Business Operations Analyst
# 19  Business Analyst / Product Analyst (Junior/Sen...
# 20                             Master Data Specialist
# 21                       Business Development Analyst
# 22                         MERCHANDISING DATA ANALYST
# 23  Business Development - Project Associate - Dat...
# 24  Associate Data Analyst- Customer Experience Gr...
#
#                                       Company  \
# 0                                 SoftwareONE
# 1                                   GeoComply
# 2                                       Agoda
# 3                                    FinAccel
# 4                              Zuellig Pharma
# 5                                   Pro-Order
# 6                                    Amanotes
# 7   Prudential Vietnam Assurance Private Ltd.
# 8                                     Katalon
# 9                           Xiaomi Technology
# 10           QuantumBlack, a McKinsey company
# 11                                     Shopee
# 12                 Hewlett Packard Enterprise
# 13                                     Shopee
# 14                                  JAC Group
# 15                                      Agoda
# 16                           SENTECHS Co. LTD
# 17                                      Agoda
# 18                 Hewlett Packard Enterprise
# 19                                   JobHopin
# 20                         Schneider Electric
# 21                                      Jabil
# 22                            Norbreeze Group
# 23                                     Shopee
# 24                                      Agoda
#
#                                        Location  \
# 0   Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 1                     Ho Chi Minh City, Vietnam
# 2   Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 3                     Ho Chi Minh City, Vietnam
# 4                     Ho Chi Minh City, Vietnam
# 5                                       Vietnam
# 6                     Ho Chi Minh City, Vietnam
# 7                     Ho Chi Minh City, Vietnam
# 8   Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 9                     Ho Chi Minh City, Vietnam
# 10  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 11  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 12  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 13                        Hanoi, Hanoi, Vietnam
# 14  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 15  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 16                    Ho Chi Minh City, Vietnam
# 17                        Hanoi, Hanoi, Vietnam
# 18                        Hanoi, Hanoi, Vietnam
# 19  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 20  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 21  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 22  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 23  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# 24  Ho Chi Minh City, Ho Chi Minh City, Vietnam
#
#                                                Detail
# 0   Why SoftwareONE?\n\nSoftwareONE is a leading g...
# 1   Posted by\nChloe Nguyen\nLooking for Senior Py...
# 2   About Agoda\n\nAgoda is an online travel booki...
# 3   Posted by\nKrisna Parapat\nAVP, Group Head of ...
# 4   The ideal candidate's favorite words are learn...
# 5   Posted by\nTrình Viễn\nHunterxxxhunter\nSend I...
# 6   ABOUT AMANOTES\nWe are Amanotes! A fast-growin...
# 7   Posted by\nTram Nguyen 2nd\nTalent Acquisition...
# 8   Posted by\nNghia (Danny) To 2nd\nGood People K...
# 9   Job Description:\nMaintenance retail data dail...
# 10  Qualifications\nBachelor or MSc or PhD level d...
# 11  Job Description\nResponsible for day-to-day ex...
# 12  Hewlett Packard Enterprise advances the way pe...
# 13  Job Description\nWork closely with Driver mana...
# 14  Company Overview\n\nThe company history and le...
# 15  About Agoda\n\nAgoda is an online travel booki...
# 16  With our expansion in Edtech projects even loc...
# 17  About Agoda\n\nAgoda is an online travel booki...
# 18  Hewlett Packard Enterprise advances the way pe...
# 19  Posted by\nQuina Ly\nLooking for Senior Busine...
# 20  About Our Company\n\nAt Schneider, we believe ...
# 21  At Jabil we strive to make ANYTHING POSSIBLE a...
# 22  This job is sourced from a job board. Learn mo...
# 23  Job Description\nApply qualitative research an...
# 24  About Agoda\n\nAgoda is an online travel booki...

# %%
driver.driver.find_element_by_xpath('')

# %%
details
# Out:
# 'Why SoftwareONE?\n\nSoftwareONE is a leading global provider of end-to-end software and cloud technology solutions, headquartered in Switzerland. With an IP and technology-driven services portfolio, it enables companies to holistically develop and implement their commercial, technology and digital transformation strategies. This is achieved by modernizing applications and migrate critical workloads on public clouds, while simultaneously managing and optimizing the related software and cloud assets and licensing. SoftwareONE’s offerings are connected by PyraCloud, its proprietary digital platform, which provides customers with data-driven, actionable intelligence. With around 7,700 employees and sales and service delivery capabilities in 90 countries, SoftwareONE provides around 65,000 business customers with software and cloud solutions from over 7,500 publishers. SoftwareONE’s shares (SWON) are listed on SIX Swiss Exchange. For more information, please visit https://www.softwareone.com/e.\n\nSoftwareONE Holding AG, Riedenmatt 4, CH-6370 Stans\n\nThe role\n\nResponsibilities:\nManaging master data, including creation, updates, and deletion.\nManaging users and user roles.\nProvide quality assurance of imported data, working with quality assurance analysts if necessary.\nCommissioning and decommissioning of data sets.\nProcessing confidential data and information according to guidelines.\nHelping develop reports and analysis.\nManaging and designing the reporting environment, including data sources, security, and metadata.\nSupporting the data warehouse in identifying and revising reporting requirements.\nSupporting initiatives for data integrity and normalization.\nAssessing tests and implementing new or upgraded software and assisting with strategic decisions on new systems.\nGenerating reports from single or multiple systems.\nTroubleshooting the reporting database environment and reports.\nEvaluating changes and updates to source production systems.\nTraining end-users on new reports and dashboards.\nProviding technical expertise in data storage structures, data mining, and data cleansing.\n\nWhat We Need To See From You\n\nRequirements:\nBachelor’s degree from an accredited university or college in computer science.\n3+ years of experience as a data analyst or in a related field.\nAbility to work with stakeholders to assess potential risks.\nAbility to analyze existing tools and databases and provide software solution recommendations.\nAbility to translate business requirements into non-technical, lay terms.\nHigh-level experience in methodologies and processes for managing large-scale databases.\nDemonstrated experience in handling large data sets and relational databases.\nUnderstanding of addressing and metadata standards.\nHigh-level written and verbal communication skills.\n\nWhat You Should Really Know About Us.\n\nStrip away everything. Strip away our brand, strip away our buildings, strip away our offices. What are we left with? Our people. This is what makes SoftwareONE successful.\n\nPassionate people who live and breathe our values every day, who delight our customers, every day, and who go above and beyond, every day. Our culture is unique, and I believe that having the right people, and empowering them to succeed, is the absolute key to our success.\n\nPatrick Winter, Founder.\n\nWhat We Expect From Our Employees\n\nSuccess at SoftwareONE is not defined by what you do for yourself, but by what you deliver for our customers, the business and for the employees around you. SoftwareONE employees are energized, agile and are laser focused on delivering world class Customer Satisfaction and results. Our leaders motivate and inspire their teams and provide a working environment that delivers incredible levels of Employee Satisfaction. We are Humble, have a very high degree of Integrity and are simply not interested in politics.\n\nOur leaders operate with a high levels of Discipline but are able to work at Speed man ...
