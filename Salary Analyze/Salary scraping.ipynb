GooAvf0CcH8RlHbZ-8e39MgVuiFDjtlafMQmbgVbgjEiI50ljN93yLWukbaEY-EXK9HvQC2SZIih7Cd9IzJaR6UEzxGdCFDxkMJ5e1hYEioRCu9fCurA3myOoNr0AJsOQLgIEPrAI_g2_dxbHTwpC1iU-vsiRmAd4QfM7kL18lobYYKfvYBmF9XpptdwHgxPYYdC2JBMeA76Xac7LXrixGwx6jBOcd77W3Sef3Tu3bzSilxCUuunPI9CZpZdcH575PaeXqcRy0046dlvGomdYXrh4iz8uwBkU6f-sAQcDf_sjk_mZa4BKGvddCDQHqTbptiznWzlzTwtSRExk4VSY32Nb6U9zXrwW2khHZrEnyhfuX0ryx50iEaUp3jHIEwCgcs_LZvG-R-c8IC8Ui1MYu-PHXZgAKJpKvw_-72DY-JzQ1q4Z0xXh-shEAdPZr_KhXGfTgvEgYO86C3bJuvQMFcDMrkpcULTBJrwLAvfDuI0Laj4owpwPsuExe4qCVDZn6lVXkFCT0I; SameSite=None; gdsid=1640742185265:1640767298798:B72CC74073D1795F09733C2781CC6C2C; _dc_gtm_UA-2595786-1=1; _ga_RC95PMVB3H=GS1.1.1640763737.3.1.1640767304.60; ev=sd-header!click-search-button!data%20analyst%7CSalary%7Clocation!null!false; AWSALB=yJmmL7uhXqAZlIlmguhfL+lj/OszhpsTU1fBlFQRcxcYRvhWFoA3vDEdYE0DH3rV4XKzLpEe+DuhUlD14PI1c8mjgXLik6jekIY0qQVkw27q64XD+WS+9QMW4FxPanU50aRJeRhzy1KMSzAt4WjORxdpPZljwJRtxBQH+iuvme50QRqbfdOTFAC1CQVjbA==; AWSALBCORS=yJmmL7uhXqAZlIlmguhfL+lj/OszhpsTU1fBlFQRcxcYRvhWFoA3vDEdYE0DH3rV4XKzLpEe+DuhUlD14PI1c8mjgXLik6jekIY0qQVkw27q64XD+WS+9QMW4FxPanU50aRJeRhzy1KMSzAt4WjORxdpPZljwJRtxBQH+iuvme50QRqbfdOTFAC1CQVjbA==; ADRUM_BTa=R:25|g:3ca8bcd8-7075-4b95-9aa4-a6fb34fd3c1a|n:glassdoor_17d346a0-2ec1-4454-86b0-73b3b787aee9; ADRUM_BT1=R:25|i:1484602|e:38|d:211; ADRUM_BT2=R:25|i:1484605|e:157|d:1; bs=MXOYh43lLu7Mual6U3rHsw:Tpdu9UogP3Tu6txl5zXLe0el_uzeFKAZfC3ZRlA17zJ2Hwu1SfO1UnyVDYTd--rxXICC66ye6Mq5nHAVtvkoGCnRquVLTMm_jzYD_-bJBZc:_faIzpcz5lvHYu8G7rAOPWseCLBEnmw93b96r8ztVKs',
}

params = (
    ('clickSource', 'searchBtn'),
)


#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29.htm?clickSource=searchBtn', headers=headers)

# %%
import scrapy
import pandas as pd

# %%
def cleanSelector(obj, xpath = './text()'):
    clean_list = []
    for i in range(len(obj)):
        if obj[i].xpath(xpath).extract():
            clean_list.append(obj[i].xpath(xpath).extract()[0]) #wtheck is this :)) 
        else:
            clean_list.append(None)
    return clean_list

def getChecked(values, checks):
    output = []
    for value, check in zip(values, checks):
        if check == 'checked':
            output.append(value)
    if output:
        return output
    else:
        output = [None]
        return output

def list2text(thelist):
    text = thelist[0]
    if len(thelist) == 1:
        return text
    else:
        for i in range(1,len(thelist)):
            text = text + ', ' + thelist[i]
        return text

# %%
data_dict = {'Company': [],
            'Job': [],
            'Salary':[]}

# %%
urls_OTT = 'https://www.glassdoor.ca/Salaries/ottawa-data-analyst-salary-SRCH_IL.0,6_IM981_KO7,19_IP{}.htm'
urls_Ottawa = []
for i in range(2,11):
    urls_Ottawa.append(urls_OTT.format(i))
print(urls_Ottawa)

# %%
urls_TRT = 'https://www.glassdoor.ca/Salaries/toronto-data-analyst-salary-SRCH_IL.0,7_IM976_KO8,20_IP{}.htm'
urls_Toronto = []
for i in range(2,11):
    urls_Toronto.append(urls_TRT.format(i))
print(urls_Toronto)

# %%
urls_NY = 'https://www.glassdoor.ca/Salaries/new-york-city-data-analyst-salary-SRCH_IL.0,13_IM615_KO14,26_IP{}.htm'
urls_NewYork = []
for i in range(2,11):
    urls_NewYork.append(urls_NY.format(i))
print(urls_NewYork)

# %%
urls_WST = 'https://www.glassdoor.ca/Salaries/washington-dc-data-analyst-salary-SRCH_IL.0,13_IM911_KO14,26_IP{}.htm'
urls_Washington = []
for i in range(2,11):
    urls_Washington.append(urls_WST.format(i))
print(urls_Washington)

# %%
urls_SF = 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP{}.htm'
urls_SanFancisco = []
for i in range(2,11):
    urls_SanFancisco.append(urls_SF.format(i))
print(urls_SanFancisco)
# Out:
# ['https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP2.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP3.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP4.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP5.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP6.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP7.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP8.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP9.htm', 'https://www.glassdoor.ca/Salaries/san-francisco-data-analyst-salary-SRCH_IL.0,13_IM759_KO14,26_IP10.htm']

# %%
urls_HCM = ['https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29.htm',
        'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP2.htm',
       'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP3.htm',
       'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP4.htm',
       'https://www.glassdoor.ca/Salaries/ho-chi-minh-city-data-analyst-salary-SRCH_IL.0,16_IM1746_KO17,29_IP5.htm']

urls_HN = ['https://www.glassdoor.ca/Salaries/hanoi-data-analyst-salary-SRCH_IL.0,5_IM1055_KO6,18.htm',
          'https://www.glassdoor.ca/Salaries/hanoi-data-analyst-salary-SRCH_IL.0,5_IM1055_KO6,18_IP2.htm',
          'https://www.glassdoor.ca/Salaries/hanoi-data-analyst-salary-SRCH_IL.0,5_IM1055_KO6,18_IP3.htm']

# %%
for url in urls_SanFancisco:
    response = requests.get(url, headers=headers, params=params)
    response = response.content
    sel = scrapy.Selector(text = response)

    company = cleanSelector(sel.xpath('//*[contains(@data-test,"employer-name")]/a'))
    job = cleanSelector(sel.xpath('//span[contains(@data-test,"job-title")]'))
    salary = cleanSelector(sel.xpath('//*[contains(@data-test,"salary-info")]/h3'))
    print(company, job, salary)
    for i in range(len(company)):
        data_dict['Company'].append(company[i])
        data_dict['Job'].append(job[i])
        data_dict['Salary'].append(salary[i])
# Out:
# ['Lundquist Consulting', 'Wells Fargo', 'Wish', 'Autodesk', 'Blue Shield Of California', 'Stripe', 'Salesforce', 'Robinhood', 'Twitch', 'Doximity', 'Meta', 'Castlight', 'KIXEYE', 'The Climate Corp', 'Fitbit', 'Bio-Rad Laboratories', 'Samba TV', 'iTradeNetwork', 'Flexport', 'Comscore'] ['Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst - Hourly Contractor', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst', 'Data Analyst'] ['US$63,458', 'US$93,679', 'US$131,152', 'US$95,312', 'US$87,103', 'US$135,226', 'US$107,472', 'US$134,986', 'US$140,000', 'US$102,584', 'US$58', 'US$112,042', 'US$91,321', 'US$107,408', 'US$108,775', 'US$90,107', 'US$93,248', 'US$85,916', 'US$98,949', 'US$92,966']
# ...

# %%
df = pd.DataFrame(data_dict)
df.to_excel('SanFanciscoSalary.xlsx', index = True)
display(data_dict)
# Out:
# {'Company': ['Lundquist Consulting',
#   'Wells Fargo',
#   'Wish',
#   'Autodesk',
#   'Blue Shield Of California',
#   'Stripe',
#   'Salesforce',
#   'Robinhood',
#   'Twitch',
#   'Doximity',
#   'Meta',
#   'Castlight',
#   'KIXEYE',
#   'The Climate Corp',
#   'Fitbit',
#   'Bio-Rad Laboratories',
#   'Samba TV',
#   'iTradeNetwork',
#   'Flexport',
#   'Comscore',
#   'Contextlogic',
#   'Pocket Gems',
#   'Robert Half',
#   'Credit Sesame',
#   'Bank of the West',
#   'Oracle',
#   'Meltwater',
#   'Autodesk',
#   'TinyCo',
#   '6sense',
#   'Genentech',
#   'Cisco Systems',
#   'FLYR',
#   'Meraki',
#   'IBM',
#   'NerdWallet',
#   'SpringML',
#   'CSAA Insurance Group, a AAA Insurer',
#   'Glassdoor',
#   'Twilio',
#   'Course Hero',
#   'J.P. Morgan',
#   'Sutter Health',
#   'Weee',
#   'Accenture',
#   'Google',
#   'Pacific Gas and Electric',
#   'RH',
#   'Tesla',
#   'Amazon',
#   'Shipt',
#   'Stanford University',
#   'Electronic Arts',
# ...
